# %% [markdown]
# # Setup

# %%
# %cd /kaggle/working/
# %rm -rf mlproduction
# !git clone https://github.com/daoanhkhoa123/mlproduction.git
# %cd /kaggle/working/mlproduction
# %pwd
# Out:
# /kaggle/working
# Cloning into 'mlproduction'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 19 (delta 5), reused 19 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 3.30 MiB | 6.02 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /kaggle/working/mlproduction
# '/kaggle/working/mlproduction'

# %%
# !pip install -q --upgrade uv
# !uv sync
# Out:
# Using CPython 3.12.12
# Creating virtual environment at: .venv
# Resolved 1 package in 2ms
# Audited in 0.01ms

# %% [markdown]
# # Running

# %%
# !pwd
# Out:
# /kaggle/working/mlproduction
